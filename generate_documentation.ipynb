# %%
import inspect
from bs4 import BeautifulSoup as bs
import re

from importlib.machinery import SourceFileLoader
# path = "C:/Users/mtlsa/Documents/UTC/GB05/TX/Python_EMGExplorer/EMG_Explorer_App/"
# name = 'EMGExplorer'
# mod = SourceFileLoader(name,path).load_module()
# import the file from wich you want to create the documentation
# it must be a .py file, if you have a Notebbok, you can copy and paste the code in a .py file and to some clean up
# !!! the .py file must not contain any import from library you don't want in the documentation
# from instance import numpy as np, importe pandas as pd must be removed from .py file
import Tube_kundt as module

# path = "C:/Users/mtlsa/Documents/UTC/GB05/TX/Python_EMGExplorer/EMG_Explorer_App/"
# name = 'EMGExplorer'
# mod = SourceFileLoader(name,path).load_module()

# %% [markdown]
# #### Get the function of a module

# %%
dir(module) # list of all functions, built in function and imported module

# %%
# retrieve a function
obj = getattr(module,'Class1')
# filter the objects
if inspect.isfunction(obj):
    print('is a function !')
elif inspect.isclass(obj):
    print('is a class !')
else:
    print('not a function ! ')

# %%
obj.__name__, obj.__doc__ # usefull information about the object

# %%
# Retrieve all the object of the module
all_obj = inspect.getmembers(module)
# Filter only the function
functions = [m for m in all_obj if inspect.isfunction(m[1])]
functions

# %%
obj_fc = getattr(module,'rms')
obj_cl = getattr(module,'Class1')

obj_fc.__doc__,obj_cl.__doc__

# %%
n = obj_cl(1)
for i in inspect.getmembers(n):
    if i[0][0] != '_':
        print(i)

#not possible to have the attributs of a class and of their methods
# plus, it would be to chaotic
# the main attributes should be summarized in the __init__ description as returns + description: the initialized attributes are described in returns section

for i in dir(obj_cl): 
    if i[0] != '_':
        print(i)

# %% [markdown]
# ## Create template

# %%
def description_object_function(obj):
    """Extract the information from an object that is a function

    Args:
        obj (object): an object

    Returns:
        desc_dict (dict) : dictionnary that stores the attributs of the object
    """
    
    # divide the sring into: description, arguments, returns
    #  desc_dict = {'name':'','type':'','input_arguments':'','summary':'','arguments':{},'returns':{},'children':{}}

    desc = obj.__doc__
    # split into lines and removes the white spaces before and after the string
    # remove the empty string
    desc_split= desc.splitlines()
    desc_split = [m.strip() for m in desc_split] 
    desc_split = list(filter(lambda x: x != "", desc_split))

    desc_dict = {'name':'','type':'','input_arguments':'','summary':'','arguments':{},'returns':{},'children':{}}

    # retrieve the arguments of the function
    desc_dict['input_arguments'] = list(obj.__code__.co_varnames) 
    desc_dict['name'] = obj.__name__
    desc_dict['type'] = 'function'

    section = 'summary'
    i = 0
    j= 0
    for sub_string in desc_split:
        
        if sub_string == 'Args:':
            section = 'arguments'
            continue
        elif sub_string == 'Returns:':
            section = 'returns'
            continue

        if section == 'arguments':
            
            # extract argument informations
            arg_detail = {'name':'','type':'','description':''}
            arg_split_1 = sub_string.split(':')
            arg_detail['description'] = ':'.join(arg_split_1[1:])
            arg_split_2 = arg_split_1[0].split('(')
            arg_detail['name'] = arg_split_2[0].strip()
            arg_detail['type'] = arg_split_2[1][:-1].strip()

            desc_dict[section][i] = arg_detail
            i+=1
            
        elif section == 'summary':
            desc_dict[section] += sub_string

        elif section == 'returns':
            return_split = sub_string.split(':')
            return_detail = {'type':'','description':''}
            return_detail['description'] = return_split[1].strip()
            return_detail['type'] = return_split[0].strip()
            desc_dict[section][j] = return_detail
            j+=1

    return desc_dict




def description_object_class(obj):
    """Extract the information from an object that is a class

    Args:
        obj (object): an object

    Returns:
        desc_dict (dict) : dictionnary that stores the attributs of the object
    """
    # divide the sring into: description, arguments, returns
    #  desc_dict = {'name':'','type':'','input_arguments':'','summary':'','arguments':{},'returns':{},'children':{}}

    desc = obj.__doc__
    # split into lines and removes the white spaces before and after the string
    # remove the empty string
    desc_split= desc.splitlines()
    desc_split = [m.strip() for m in desc_split] 
    desc_split = list(filter(lambda x: x != "", desc_split))

    desc_dict = {'name':'','type':'','input_arguments':'','summary':'','arguments':{},'returns':{},'children':{}}

    # retrieve the arguments of the function
    print(obj.__name__)
    try: desc_dict['input_arguments'] = list(obj.__code__.co_varnames) 
    except: pass
    desc_dict['name'] = obj.__name__
    desc_dict['type'] = 'function'

    section = 'summary'
    i = 0
    j= 0
    for sub_string in desc_split:
        
        if sub_string == 'Args:':
            section = 'arguments'
            continue
        elif sub_string == 'Returns:':
            section = 'returns'
            continue

        if section == 'arguments':
            
            # extract argument informations
            arg_detail = {'name':'','type':'','description':''}
            arg_split_1 = sub_string.split(':')
            arg_detail['description'] = ':'.join(arg_split_1[1:])
            arg_split_2 = arg_split_1[0].split('(')
            arg_detail['name'] = arg_split_2[0].strip()
            arg_detail['type'] = arg_split_2[1][:-1].strip()

            desc_dict[section][i] = arg_detail
            i+=1
            
        elif section == 'summary':
            desc_dict[section] += sub_string

        elif section == 'returns':
            return_split = sub_string.split(':')
            return_detail = {'type':'','description':''}
            return_detail['description'] = return_split[1].strip()
            return_detail['type'] = return_split[0].strip()
            desc_dict[section][j] = return_detail
            j+=1

    return desc_dict

# %%
def has_children(obj_all):   
    """Test wether or not an object has method on its own. The function returns True if there is any.

    Args:
        obj_all (object): an object

    Returns:
        bool (bool) : True if the object has children.
    """
    
    for obj in inspect.getmembers(obj_all): # [('av_mean', <function test_import_doc.av_mean(amplitudes, N=10)>),
        if obj[0][0] != '_':
            return True
        
    return False

# %%
def get_desc_children(module):
    """Extract the descriptions of all the functions/classes of a module.

    Args:
        module (module): module

    Returns:
        list_f (list): list of dictionnary that store the description of each function or class.
    """
    
    list_f = []
    for obj in inspect.getmembers(module): # [('av_mean', <function test_import_doc.av_mean(amplitudes, N=10)>),
        if obj[0][0] != '_':
            
            print(obj[1].__name__)
            desc_dict = {'name':'','type':'','input_arguments':'','summary':'','arguments':{},'returns':{},'children':{}}

            if inspect.isfunction(obj[1]) :
                desc_dict = description_object_function(obj[1])
            elif inspect.isclass(obj[1]):
                desc_dict = description_object_class(obj[1])

            if has_children(obj[1]):
                desc_dict['children'] = get_desc_children(obj[1])

            list_f += [ desc_dict ]

    return list_f

# %%
def html_arg(arguments):
    if arguments != {}:
        string = '<div class="arg_return_band">Arguments:</div><ul>'
        for arg in list(arguments.values()):
            string+=f'<li>{arg["name"]}({arg["type"]}): {arg["description"]}</li>'
            
        string += '</ul>'
        return string
    return ''

def html_ret(returns):
    if returns != {}:
        string = '<div class="arg_return_band">Returns:</div><ul>'
        for ret in list(returns.values()):
            string += f'<li>{ret["type"]}: {ret["description"]}</li>'
        string += '</ul>'
        return string
    return ''

def html_child(children):
    if children != {}:
        string = '<div class="arg_return_band">Children:</div><ul>'
        for child_name in [child['name'] for child in children]:
            string += f'<li><a href="#{child_name}" class="a_child">{child_name}</a></li>'
        string += '</ul>'
        return string
    return ''

def html_block_function(description):
    # html_fc = f'<h3  class="func_name" >' + description["name"] + f'<a id="{description["name"]}"></a>'
    html_fc = f'<h3  class="func_name" >' + description["name"] + f'<a name="{description["name"]}"></a>'
    html_fc += '</h3> <div class="func_info"><p class="p_summary"> '+ description["summary"]+' </p>'
    html_fc += html_arg(description['arguments'])
    html_fc += html_ret(description['returns'])
    html_fc += html_child(description['children'])
    html_fc += '</div>'

    return html_fc

# %%
def html_link_function(description_object_dict):
    return f'<li><a href="#{description_object_dict["name"]}" class="a_sum">{description_object_dict["name"]}</a></li>'

def get_html_children(obj_desc_all):
    html_link = '<ul>'
    html_fc = ''

    for obj_desc in obj_desc_all: # [('av_mean', <function test_import_doc.av_mean(amplitudes, N=10)>),
        print(obj_desc)
        html_fc += html_block_function(obj_desc) # add the list of child in block function
        html_link += html_link_function(obj_desc)

        if obj_desc['children'] !={}:
            # add list of link
            html_link_child,html_fc_child = get_html_children(obj_desc['children'])
            html_link +=  html_link_child
            html_fc +=  html_fc_child

    html_link += '</ul>'

    return html_link,html_fc

# %%
def create_html(module,file_name='Kundt_doc.html',template_name = 'template.html'):
    general_json = get_desc_children(module)
    html_link,html_fc = get_html_children(general_json) 

    # open the template to be modified
    html = open( template_name)
    
    # sarse HTML file with Beautiful Soup
    soup = bs(html, 'html.parser')
    
    # store the text to be altered
    old_text = soup.find("div", {"class": "split_summary"})
    old_text2 = soup.find("div", {"class": "split_main"})
    
    # replace the stored text with the new text
    new_text = old_text.find(text=re.compile(
        '[LINK]')).replace_with(bs(html_link, 'html.parser'))
    
    new_text2 = old_text2.find(text=re.compile(
        '[FUNCTION]')).replace_with(bs(html_fc, 'html.parser'))
    
    # create a new html file
    with open(file_name, "w", encoding = 'utf-8') as f_output:
        f_output.write(soup.prettify())
        f_output.close()

# %%
create_html(module,file_name='Renouveau.html')
# Out:
# All_Signal
# All_Signal
# add_signal
# del_signal
# rename_signal
# Calibration
# Calibration
# init_interactivity
# init_label_setup
# init_widget
# init_widget_plot
# oc_H
# oc_SNR
# oc_calibration
# oc_clear
# oc_dropdown_tube
# oc_result
# oc_result_SNR
# pop_data_fig
# pop_data_fig_m
# return_transfert_function
# update_layout_int
# Measurement
# Measurement
# filter_hampel_averaging
# init_interactivity
# init_interactivity_plot
# init_widgets
# init_widgets_plot
# oc_button_add
# oc_button_combine
# oc_button_delete
# oc_button_html
# oc_button_legend
# oc_button_measure
# oc_button_rename
# oc_checkbox_hampel_averaging
# oc_checkbox_range
# oc_clear_figure
# oc_dropdown_tube
# oc_plot_multiple
# oc_slider_hampel_averaging
# update_list
# update_name
# Parameters
# Parameters
# SNR
# TaskAcquisitionGeneration
# TaskAcquisitionGeneration
# callable_stop_generation
# callback_function
# callback_stop_acquisition
# close_task
# convert
# convert_and_filter_acquired_signal
# creation_white_noise_frequency_band
# filter_BP
# generation_sine_wave
# generation_white_noise
# measurement
# open_from_json
# plot_acquired_signal
# plot_av_fft
# plot_fft_generated_signal
# plot_generated_signal
# save_to_cjson
# simple_acquisition
# start_acquisition
# average_smoothing
# combine_metric
# computation_R_coefficient
# computation_Z_impedance
# computation_a_coefficient
# compute_H12
# compute_coherence
# frequencies_limits
# hampel_filter
# plot_av_fft_m
# plot_computation_metric_m
# rms
# spectro_average
# {'name': 'All_Signal', 'type': 'function', 'input_arguments': '', 'summary': 'Class to gather all the Signal (TaskAcquisitionGeneration). The class comprises methods to add a new signal, delete a signal and rename a signal', 'arguments': {}, 'returns': {}, 'children': [{'name': 'add_signal', 'type': 'function', 'input_arguments': ['self', 'parameters', 'name', 'tube', 'material', 'resonator', 'new_signal'], 'summary': 'Adds a signal (TaskAcquisitionGeneration). The signal will not be added if one signal already has the same name.', 'arguments': {0: {'name': 'parameters', 'type': 'Paramete', 'description': 'class): parameter of the signal'}, 1: {'name': 'name', 'type': 'str', 'description': ' name of the signal'}, 2: {'name': 'tube', 'type': 'str', 'description': ' tube used during acquisition of the signal'}, 3: {'name': 'material', 'type': 'str', 'description': ' material used during acquisition of the signal'}, 4: {'name': 'resonator', 'type': 'str', 'description': ' resonator used during acquisition of the signal'}}, 'returns': {}, 'children': {}}, {'name': 'del_signal', 'type': 'function', 'input_arguments': ['self', 'name'], 'summary': 'Remove a signal from the class.', 'arguments': {0: {'name': 'name', 'type': 'str', 'description': ' name of the signal to remove'}}, 'returns': {}, 'children': {}}, {'name': 'rename_signal', 'type': 'function', 'input_arguments': ['self', 'old_name', 'new_name', 'signal'], 'summary': 'This method renames a signal if the chosen name is not already attributed.', 'arguments': {0: {'name': 'old_name', 'type': 'str', 'description': ' name of the signal to rename'}, 1: {'name': 'new_name', 'type': 'str', 'description': ' new name of the signal'}}, 'returns': {}, 'children': {}}]}
# {'name': 'add_signal', 'type': 'function', 'input_arguments': ['self', 'parameters', 'name', 'tube', 'material', 'resonator', 'new_signal'], 'summary': 'Adds a signal (TaskAcquisitionGeneration). The signal will not be added if one signal already has the same name.', 'arguments': {0: {'name': 'parameters', 'type': 'Paramete', 'description': 'class): parameter of the signal'}, 1: {'name': 'name', 'type': 'str', 'description': ' name of the signal'}, 2: {'name': 'tube', 'type': 'str', 'description': ' tube used during acquisition of the signal'}, 3: {'name': 'material', 'type': 'str', 'description': ' material used during acquisition of the signal'}, 4: {'name': 'resonator', 'type': 'str', 'description': ' resonator used during acquisition of the signal'}}, 'returns': {}, 'children': {}}
# {'name': 'del_signal', 'type': 'function', 'input_arguments': ['self', 'name'], 'summary': 'Remove a signal from the class.', 'arguments': {0: {'name': 'name', 'type': 'str', 'description': ' name of the signal to remove'}}, 'returns': {}, 'children': {}}
# {'name': 'rename_signal', 'type': 'function', 'input_arguments': ['self', 'old_name', 'new_name', 'signal'], 'summary': 'This method renames a signal if the chosen name is not already attributed.', 'arguments': {0: {'name': 'old_name', 'type': 'str', 'description': ' name of the signal to rename'}, 1: {'name': 'new_name', 'type': 'str', 'description': ' new name of the signal'}}, 'returns': {}, 'children': {}}
# {'name': 'Calibration', 'type': 'function', 'input_arguments': '', 'summary': "Class that defines the first 2 tabs of the interface : Calibration and acquired Signal.This Class comprises the function to perform the calibration of the microphone, compute the SNR and compute the corrected transfert function.The acquired signal and their fourier transform are displayed in the tab 'acquired signal'.Function with the prefix 'oc' are the callback functions of the interactive element of the same name. For instance, oc_dropdown_tube is the function called when the value of dropdown_tube is changed.Each element has the prefix of its type, for instance, button_calibration_mic_1 and dropdown_tube are respectively button and dropdown.", 'arguments': {}, 'returns': {}, 'children': [{'name': 'init_interactivity', 'type': 'function', 'input_arguments': ['self'], 'summary': 'Define all the interaction between the elements of the interface and the methods of the class', 'arguments': {}, 'returns': {}, 'children': {}}, {'name': 'init_label_setup', 'type': 'function', 'input_arguments': ['self'], 'summary': "Initialize the label of the tab 'Calibration' and the dropdown for the Set Up", 'arguments': {}, 'returns': {}, 'children': {}}, {'name': 'init_widget', 'type': 'function', 'input_arguments': ['self', 'init_scatter'], 'summary': "Initialize the element of the tab 'Calibration'", 'arguments': {}, 'returns': {}, 'children': {}}, {'name': 'init_widget_plot', 'type': 'function', 'input_arguments': ['self', 'init_scatter'], 'summary': "Initialize all the element if the tab 'acquired signal'", 'arguments': {}, 'returns': {}, 'children': {}}, {'name': 'oc_H', 'type': 'function', 'input_arguments': ['self', 'np_p', 'arg'], 'summary': 'Calls the function that computes the transfert function with the adequat arguments depending on the setting of the acquisition and assign the result to the right variable.', 'arguments': {0: {'name': 'np_p', 'type': 'int', 'description': ' 0 if the microphones are swapped, otherwise 1'}, 1: {'name': 'arg', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}, {'name': 'oc_SNR', 'type': 'function', 'input_arguments': ['self', 'noise_sig', 'arg', 'duration'], 'summary': "The function displays the fourier transforms in dB of a noise recording and a signal recording that will allow a visual inspection if an SNR > 10 dB is met.First, an acquisition is started, then the figures on the 'acquired samples' tab are updated.", 'arguments': {0: {'name': 'noise_sig', 'type': 'int', 'description': ' 0 if the acquired signal if noise, 1 if the acquired signal is white noise'}, 1: {'name': 'arg', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}, {'name': 'oc_calibration', 'type': 'function', 'input_arguments': ['self', 'arg', 'param', 'duration', 'mic', 'sig', 'amp', 'freq', 'max_amp', 'freq_max'], 'summary': "This function computes the sensitivity of the microphones. The calibration takes 15 seconds.When the user calibrates a microphone, the microphone concerned is detected as the one with the highest amplitude signal between the signals of the 2 microphones.When the acquisition is complete, the amplitude spectrum of the signal is calculated and the maximum amplitude, reached around 1000 Hz in this case, is extracted: this is the calibration constant of the microphone.Once the constant is extracted, it is stored in the general parameters and the acquired signal is converted to Pascal.The acquired signal and its fourier transform are then displayed in the 'Acquired Signal' tab.", 'arguments': {0: {'name': 'arg', 'type': '', 'description': ' callback argument'}}, 'returns': {0: {'type': 'calibration_cst(float)', 'description': 'attribut of the class Parameter, the calibration constant of the parameter is update with the computed value.'}}, 'children': {}}, {'name': 'oc_clear', 'type': 'function', 'input_arguments': ['self', 'arg', 'fig'], 'summary': 'Clear the figure by maki ...
# {'name': 'init_interactivity', 'type': 'function', 'input_arguments': ['self'], 'summary': 'Define all the interaction between the elements of the interface and the methods of the class', 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'init_label_setup', 'type': 'function', 'input_arguments': ['self'], 'summary': "Initialize the label of the tab 'Calibration' and the dropdown for the Set Up", 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'init_widget', 'type': 'function', 'input_arguments': ['self', 'init_scatter'], 'summary': "Initialize the element of the tab 'Calibration'", 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'init_widget_plot', 'type': 'function', 'input_arguments': ['self', 'init_scatter'], 'summary': "Initialize all the element if the tab 'acquired signal'", 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'oc_H', 'type': 'function', 'input_arguments': ['self', 'np_p', 'arg'], 'summary': 'Calls the function that computes the transfert function with the adequat arguments depending on the setting of the acquisition and assign the result to the right variable.', 'arguments': {0: {'name': 'np_p', 'type': 'int', 'description': ' 0 if the microphones are swapped, otherwise 1'}, 1: {'name': 'arg', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_SNR', 'type': 'function', 'input_arguments': ['self', 'noise_sig', 'arg', 'duration'], 'summary': "The function displays the fourier transforms in dB of a noise recording and a signal recording that will allow a visual inspection if an SNR > 10 dB is met.First, an acquisition is started, then the figures on the 'acquired samples' tab are updated.", 'arguments': {0: {'name': 'noise_sig', 'type': 'int', 'description': ' 0 if the acquired signal if noise, 1 if the acquired signal is white noise'}, 1: {'name': 'arg', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_calibration', 'type': 'function', 'input_arguments': ['self', 'arg', 'param', 'duration', 'mic', 'sig', 'amp', 'freq', 'max_amp', 'freq_max'], 'summary': "This function computes the sensitivity of the microphones. The calibration takes 15 seconds.When the user calibrates a microphone, the microphone concerned is detected as the one with the highest amplitude signal between the signals of the 2 microphones.When the acquisition is complete, the amplitude spectrum of the signal is calculated and the maximum amplitude, reached around 1000 Hz in this case, is extracted: this is the calibration constant of the microphone.Once the constant is extracted, it is stored in the general parameters and the acquired signal is converted to Pascal.The acquired signal and its fourier transform are then displayed in the 'Acquired Signal' tab.", 'arguments': {0: {'name': 'arg', 'type': '', 'description': ' callback argument'}}, 'returns': {0: {'type': 'calibration_cst(float)', 'description': 'attribut of the class Parameter, the calibration constant of the parameter is update with the computed value.'}}, 'children': {}}
# {'name': 'oc_clear', 'type': 'function', 'input_arguments': ['self', 'arg', 'fig'], 'summary': 'Clear the figure by making the traces invisible.', 'arguments': {0: {'name': 'arg', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_dropdown_tube', 'type': 'function', 'input_arguments': ['self', 'change', 'value'], 'summary': 'Update the setting of the acquisition (small or large tube)', 'arguments': {0: {'name': 'change', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_result', 'type': 'function', 'input_arguments': ['self', 'arg', 'H_p', 'H_np', 'range', 'y_p', 'y_np'], 'summary': 'Plot the amplitude spectrum of the transfert function of microphones 1 and 2 when the microphones were swapped and not swapped.Additionally the function computes the correction of the transfert function L1/L2 and stores the result in the Parameters.', 'arguments': {0: {'name': 'arg', 'type': '_type_', 'description': ' _description_'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_result_SNR', 'type': 'function', 'input_arguments': ['self', 'arg', 'range'], 'summary': 'Plot the FT of the signal acquired for SNR inspection. It is recommanded that SNR should be greater than 10 dB.', 'arguments': {0: {'name': 'arg', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'pop_data_fig', 'type': 'function', 'input_arguments': ['self', 'fig', 'name', 'idx', 'new_data', 'e'], 'summary': 'Remove a trace from the figure according to a given name.', 'arguments': {0: {'name': 'fig', 'type': 'go.Figure', 'description': ' figure on wich the trace should be remove'}, 1: {'name': 'name', 'type': 'str', 'description': ' name of the trace to remove'}}, 'returns': {}, 'children': {}}
# {'name': 'pop_data_fig_m', 'type': 'function', 'input_arguments': ['self', 'name', 'i'], 'summary': 'Remove the traces from multiple plots of one acquisition.', 'arguments': {0: {'name': 'name', 'type': 'str', 'description': ' name of the trace'}}, 'returns': {}, 'children': {}}
# {'name': 'return_transfert_function', 'type': 'function', 'input_arguments': ['self', 'np_p', 'Task_norm', 'temp', 'duration', 'fft_np_mic_2', 'fft_np_mic_1', 'frequencies_n', 'H_'], 'summary': 'The function compute the transfert function fo microphone 1 and 2. The acquisition of white noise to compute the transfert function if 60 secondes then the function calls spectro_average, as a consequence, the resulting ratio is not a 1D array but has as many row asthere were segments in the computation of the spectrogram.', 'arguments': {0: {'name': 'np_p', 'type': 'str', 'description': ' p if the microphones are swapped, np otherwise'}}, 'returns': {0: {'type': 'H_(array)', 'description': 'array where each row correspond to the transfert function computed for one segment of the signals.'}}, 'children': {}}
# {'name': 'update_layout_int', 'type': 'function', 'input_arguments': ['self', 'box_layout', 'k'], 'summary': 'Define the layout of the calibration interface', 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'Measurement', 'type': 'function', 'input_arguments': '', 'summary': "This class defines the elements and interactivity of the tabs 'plot' and 'Measurement', plus, it comprises the class Calibration.", 'arguments': {}, 'returns': {}, 'children': [{'name': 'filter_hampel_averaging', 'type': 'function', 'input_arguments': ['self', 'sig', 'new_sig', 'n_sigma', 'win'], 'summary': 'Filter the input signal with hampel filter or/and averaging filter if the corresponding checkboxes are checked.', 'arguments': {0: {'name': 'sig', 'type': 'array', 'description': ' values to be filtered'}}, 'returns': {0: {'type': 'new_sig (array)', 'description': 'filtered values'}}, 'children': {}}, {'name': 'init_interactivity', 'type': 'function', 'input_arguments': ['self'], 'summary': "Define the interaction of the tab 'Measurement'", 'arguments': {}, 'returns': {}, 'children': {}}, {'name': 'init_interactivity_plot', 'type': 'function', 'input_arguments': ['self'], 'summary': 'Initialize the interactivites of the tab Plot', 'arguments': {}, 'returns': {}, 'children': {}}, {'name': 'init_widgets', 'type': 'function', 'input_arguments': ['self', 'layout_button_measurement'], 'summary': 'Initialize the elements of the tab Measurement', 'arguments': {}, 'returns': {}, 'children': {}}, {'name': 'init_widgets_plot', 'type': 'function', 'input_arguments': ['self', 'layout_parameters', 'layout_parameters2', 'init_scatter'], 'summary': "Initialize the elements of the tab 'plot' and some part of the layout", 'arguments': {}, 'returns': {}, 'children': {}}, {'name': 'oc_button_add', 'type': 'function', 'input_arguments': ['self', 'button', 'tube', 'material', 'resonator', 'name'], 'summary': 'Add a new signal to the instance of All_Signal that stores all the signals.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}, {'name': 'oc_button_combine', 'type': 'function', 'input_arguments': ['self', 'button', 'selected_names', 'signal_large', 'signal_small', 'tube', 'material', 'resonator', 'name', 'i'], 'summary': 'Combine the selected signals. Combined signals have 2 additional attributes compared to the usual signals of the class:signal_large and signal_small wich strore the signal that needs to be combined.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {0: {'type': 'int (int)', 'description': 'return 0 is the 2 signals are not in a large and small configuration'}, 1: {'type': 'combined signal(TaskAcquisitionGeneration)', 'description': 'the new signal is added to the instance of All_Signal that stores all the signal.'}}, 'children': {}}, {'name': 'oc_button_delete', 'type': 'function', 'input_arguments': ['self', 'button', 'selected_name'], 'summary': 'Delete the selected signal from the list of all signals.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}, {'name': 'oc_button_html', 'type': 'function', 'input_arguments': ['self', 'button', 'config'], 'summary': 'This function opens the figure of the tab plot in a web browser. It allows the figure to be displayed with larger dimensions and to be saved with a higher quality.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}, {'name': 'oc_button_legend', 'type': 'function', 'input_arguments': ['self', 'button'], 'summary': 'Update the title and legends of the figure of the tab plot according to the input of the corresponding fields.The input fields are reset once the updates are made.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback function'}}, 'returns': {}, 'children': {}}, {'name': 'oc_button_measure', 'type': 'function', 'input_arguments': ['self', 'button', 'selected_name', 'signal'], 'summary': 'records white noise for 60 secondes and stores the acquired samples in the selected signal.', 'arguments': {0: {'nam ...
# {'name': 'filter_hampel_averaging', 'type': 'function', 'input_arguments': ['self', 'sig', 'new_sig', 'n_sigma', 'win'], 'summary': 'Filter the input signal with hampel filter or/and averaging filter if the corresponding checkboxes are checked.', 'arguments': {0: {'name': 'sig', 'type': 'array', 'description': ' values to be filtered'}}, 'returns': {0: {'type': 'new_sig (array)', 'description': 'filtered values'}}, 'children': {}}
# {'name': 'init_interactivity', 'type': 'function', 'input_arguments': ['self'], 'summary': "Define the interaction of the tab 'Measurement'", 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'init_interactivity_plot', 'type': 'function', 'input_arguments': ['self'], 'summary': 'Initialize the interactivites of the tab Plot', 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'init_widgets', 'type': 'function', 'input_arguments': ['self', 'layout_button_measurement'], 'summary': 'Initialize the elements of the tab Measurement', 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'init_widgets_plot', 'type': 'function', 'input_arguments': ['self', 'layout_parameters', 'layout_parameters2', 'init_scatter'], 'summary': "Initialize the elements of the tab 'plot' and some part of the layout", 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'oc_button_add', 'type': 'function', 'input_arguments': ['self', 'button', 'tube', 'material', 'resonator', 'name'], 'summary': 'Add a new signal to the instance of All_Signal that stores all the signals.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_button_combine', 'type': 'function', 'input_arguments': ['self', 'button', 'selected_names', 'signal_large', 'signal_small', 'tube', 'material', 'resonator', 'name', 'i'], 'summary': 'Combine the selected signals. Combined signals have 2 additional attributes compared to the usual signals of the class:signal_large and signal_small wich strore the signal that needs to be combined.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {0: {'type': 'int (int)', 'description': 'return 0 is the 2 signals are not in a large and small configuration'}, 1: {'type': 'combined signal(TaskAcquisitionGeneration)', 'description': 'the new signal is added to the instance of All_Signal that stores all the signal.'}}, 'children': {}}
# {'name': 'oc_button_delete', 'type': 'function', 'input_arguments': ['self', 'button', 'selected_name'], 'summary': 'Delete the selected signal from the list of all signals.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_button_html', 'type': 'function', 'input_arguments': ['self', 'button', 'config'], 'summary': 'This function opens the figure of the tab plot in a web browser. It allows the figure to be displayed with larger dimensions and to be saved with a higher quality.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_button_legend', 'type': 'function', 'input_arguments': ['self', 'button'], 'summary': 'Update the title and legends of the figure of the tab plot according to the input of the corresponding fields.The input fields are reset once the updates are made.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback function'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_button_measure', 'type': 'function', 'input_arguments': ['self', 'button', 'selected_name', 'signal'], 'summary': 'records white noise for 60 secondes and stores the acquired samples in the selected signal.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {0: {'type': 'acquired_samples(array)', 'description': 'attribut of the selected signal, the array acquired_samples of the selected signal is filled with the recorded samples.'}}, 'children': {}}
# {'name': 'oc_button_rename', 'type': 'function', 'input_arguments': ['self', 'button', 'selected_name', 'name'], 'summary': 'rename the selected signal if the name is not already used', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_checkbox_hampel_averaging', 'type': 'function', 'input_arguments': ['self', 'arg', 'traces_names', 'range_xaxis', 'name_tr', 'metric', 'signal', 'mic', 'merged_metric', 'freq', 'metric_title', 'n_sigma', 'win', 'new_data', 'data', 'new_y'], 'summary': 'Redraw all traces to get ride of previous filtered traces and filter the newly drawn traces if the filters are activated.If both hampel filter and averaging filter are activated, hampel filter is used first.', 'arguments': {0: {'name': 'arg', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_checkbox_range', 'type': 'function', 'input_arguments': ['self', 'arg'], 'summary': 'When checked, the x axis range cursor is visible, when uncheck, the range cursor is removed.', 'arguments': {0: {'name': 'arg', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_clear_figure', 'type': 'function', 'input_arguments': ['self', 'button'], 'summary': 'Remove all data from the figure of the tab plot and reset its layout.', 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_dropdown_tube', 'type': 'function', 'input_arguments': ['self', 'change', 'value'], 'summary': 'dropdown that specifies the setting of the acquisition: large or small tube.If the value corresponds to the large tube, then the user can select a material and/or a resonator.If the value corresponds to the small tube, then the user can only select a material.Changing the setting affects the description of the signal wich is used in multiple function to distinguish the small-tube signals from the large-tube ones.', 'arguments': {0: {'name': 'change', 'type': 'dict', 'description': ' callback argument, it stores the current value of the dropdown'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_plot_multiple', 'type': 'function', 'input_arguments': ['self', 'button', 'selected_signals', 'selected_plot', 'metric', 'range_xaxis', 'signal', 'selected_plot_function', 'merged_metric', 'freq', 'metric_h0', 'metric_h1', 'metric_h', 'metric_title'], 'summary': "Plot the multiple signal according to the user's selection and the selected metric.This function computes the metric and filters the results before displaying them.", 'arguments': {0: {'name': 'button', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'oc_slider_hampel_averaging', 'type': 'function', 'input_arguments': ['self', 'change'], 'summary': 'Whenever the slider are changed, check if the averaging filter or the hampel filter are activated before filtering the signal by calling the function oc_checkbox_hampel_averaging.', 'arguments': {0: {'name': 'change', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'update_list', 'type': 'function', 'input_arguments': ['self'], 'summary': "Update the lists of all the signals of the interface in tab 'Measurement' and 'Plot' according to the list of signals stored in the instance of the class All_Signal.", 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'update_name', 'type': 'function', 'input_arguments': ['self', 'change', 'get_key'], 'summary': 'As the user specifies the caracteristic of the signal acquisition, a pre-made name is updated with the informations to simplify the naming of the signal.This function is in charge of updating the name by retrieving the information of the input fields.', 'arguments': {0: {'name': 'change', 'type': '', 'description': ' callback argument'}}, 'returns': {}, 'children': {}}
# {'name': 'Parameters', 'type': 'function', 'input_arguments': '', 'summary': 'Class that contains the parameters of the Task/Signal. These parameters are :- the calibration constant of each microphones- the calibration transfert function of the large and small tube- the frequency precision- the maximum and minimum frequencies reached by the large and the small tube', 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'SNR', 'type': 'function', 'input_arguments': ['x_noise', 'x_signal', 'SNR'], 'summary': 'Computes the SNR from 2 signals: with and without noise.', 'arguments': {0: {'name': 'x_noise', 'type': 'array', 'description': ' values of the recorded noise.'}, 1: {'name': 'x_signal', 'type': 'array', 'description': ' values of the recorded signal.'}}, 'returns': {0: {'type': 'SNR(float)', 'description': 'Signal to Noise ratio'}}, 'children': {}}
# {'name': 'TaskAcquisitionGeneration', 'type': 'function', 'input_arguments': '', 'summary': 'Class for acquisition and generation of a signal, a task represents a measure or a generation to be achieved.Among its attributs, the class stores for each signal its caracteristic such as its name, the tube size, the material used ....In addition to the signal generation and acquisition functions, this class includes functions for displaying generated/acquired signals and their Fourier transforms.', 'arguments': {}, 'returns': {}, 'children': [{'name': 'callable_stop_generation', 'type': 'function', 'input_arguments': ['self', 'task_handle', 'status', 'callback_data'], 'summary': 'Stops the generation task when the generation has finished', 'arguments': {0: {'name': 'task_handle', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 1: {'name': 'status', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 2: {'name': 'callback_data', 'type': '', 'description': ' arguments automatically sent with the callback function'}}, 'returns': {}, 'children': {}}, {'name': 'callback_function', 'type': 'function', 'input_arguments': ['self', 'task_handle', 'every_n_samples_event_type', 'number_of_samples', 'callback_data', 'read'], 'summary': 'This function is called when the given number of samples has been acquired into the buffer in order to save the acquired samples.', 'arguments': {0: {'name': 'task_handle', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 1: {'name': 'every_n_samples_event_type', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 2: {'name': 'number_of_samples', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 3: {'name': 'callback_data', 'type': '', 'description': ' arguments automatically sent with the callback function'}}, 'returns': {0: {'type': 'acquired_samples (array)', 'description': 'attribut, 2-line array of the acquired samples'}}, 'children': {}}, {'name': 'callback_stop_acquisition', 'type': 'function', 'input_arguments': ['self', 'task_handle', 'status', 'callback_data'], 'summary': 'Stops the acquisition task when the acquisition is finished', 'arguments': {0: {'name': 'task_handle', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 1: {'name': 'status', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 2: {'name': 'callback_data', 'type': '', 'description': ' arguments automatically sent with the callback function'}}, 'returns': {}, 'children': {}}, {'name': 'close_task', 'type': 'function', 'input_arguments': ['self'], 'summary': 'Closes the acquisition and generation task when called. Once closed, the task need to be created again to be started.', 'arguments': {}, 'returns': {}, 'children': {}}, {'name': 'convert', 'type': 'function', 'input_arguments': ['self', 'i'], 'summary': 'Coverts the signal from voltage to pressure with the calibration constant', 'arguments': {}, 'returns': {}, 'children': {}}, {'name': 'convert_and_filter_acquired_signal', 'type': 'function', 'input_arguments': ['self', 'i'], 'summary': 'Demeans the acquired signals from the 2 microphones to remove eventual offset', 'arguments': {}, 'returns': {}, 'children': {}}, {'name': 'creation_white_noise_frequency_band', 'type': 'function', 'input_arguments': ['self', 'amp', 'mean', 'std', 'order', 'min_freq', 'max_freq', 'sos'], 'summary': 'Create a white noise with frequency band [1,8000] then generate this signal at the same time as an acquisition is started.', 'arguments': {0: {'name': 'amp', 'type': 'float', 'description': ' Amplitude of the generated signal. Defaults to 0.25.'}}, 'returns': {}, 'children': {}}, {'name': 'filter_BP', 'type': 'function', 'input_arguments': ['self', 'order', 'fc', 'i', 'sos'], 'summary': 'filter the acquired signal', 'arguments': {}, 'returns': {}, ...
# {'name': 'callable_stop_generation', 'type': 'function', 'input_arguments': ['self', 'task_handle', 'status', 'callback_data'], 'summary': 'Stops the generation task when the generation has finished', 'arguments': {0: {'name': 'task_handle', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 1: {'name': 'status', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 2: {'name': 'callback_data', 'type': '', 'description': ' arguments automatically sent with the callback function'}}, 'returns': {}, 'children': {}}
# {'name': 'callback_function', 'type': 'function', 'input_arguments': ['self', 'task_handle', 'every_n_samples_event_type', 'number_of_samples', 'callback_data', 'read'], 'summary': 'This function is called when the given number of samples has been acquired into the buffer in order to save the acquired samples.', 'arguments': {0: {'name': 'task_handle', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 1: {'name': 'every_n_samples_event_type', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 2: {'name': 'number_of_samples', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 3: {'name': 'callback_data', 'type': '', 'description': ' arguments automatically sent with the callback function'}}, 'returns': {0: {'type': 'acquired_samples (array)', 'description': 'attribut, 2-line array of the acquired samples'}}, 'children': {}}
# {'name': 'callback_stop_acquisition', 'type': 'function', 'input_arguments': ['self', 'task_handle', 'status', 'callback_data'], 'summary': 'Stops the acquisition task when the acquisition is finished', 'arguments': {0: {'name': 'task_handle', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 1: {'name': 'status', 'type': '', 'description': ' arguments automatically sent with the callback function'}, 2: {'name': 'callback_data', 'type': '', 'description': ' arguments automatically sent with the callback function'}}, 'returns': {}, 'children': {}}
# {'name': 'close_task', 'type': 'function', 'input_arguments': ['self'], 'summary': 'Closes the acquisition and generation task when called. Once closed, the task need to be created again to be started.', 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'convert', 'type': 'function', 'input_arguments': ['self', 'i'], 'summary': 'Coverts the signal from voltage to pressure with the calibration constant', 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'convert_and_filter_acquired_signal', 'type': 'function', 'input_arguments': ['self', 'i'], 'summary': 'Demeans the acquired signals from the 2 microphones to remove eventual offset', 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'creation_white_noise_frequency_band', 'type': 'function', 'input_arguments': ['self', 'amp', 'mean', 'std', 'order', 'min_freq', 'max_freq', 'sos'], 'summary': 'Create a white noise with frequency band [1,8000] then generate this signal at the same time as an acquisition is started.', 'arguments': {0: {'name': 'amp', 'type': 'float', 'description': ' Amplitude of the generated signal. Defaults to 0.25.'}}, 'returns': {}, 'children': {}}
# {'name': 'filter_BP', 'type': 'function', 'input_arguments': ['self', 'order', 'fc', 'i', 'sos'], 'summary': 'filter the acquired signal', 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'generation_sine_wave', 'type': 'function', 'input_arguments': ['self', 'duration', 'amplitude', 'frequence'], 'summary': 'Allows you to create a sinusoidal signal that will be generated at the same time as an acquisition is started.', 'arguments': {0: {'name': 'duration', 'type': 'int', 'description': ' duration of the signal (sec)'}, 1: {'name': 'amplitude', 'type': 'float', 'description': ' amplitude 0 to pic of the sine wave'}, 2: {'name': 'frequence', 'type': 'float', 'description': ' frequence of the signal'}}, 'returns': {}, 'children': {}}
# {'name': 'generation_white_noise', 'type': 'function', 'input_arguments': ['self', 'duration'], 'summary': 'Create a white noise with frequency band [10,7000] and starts a task for generation and acquisition', 'arguments': {0: {'name': 'duration', 'type': 'int', 'description': ' Duration (sec) of the generated signal'}}, 'returns': {}, 'children': {}}
# {'name': 'measurement', 'type': 'function', 'input_arguments': ['self'], 'summary': 'Make the acquisition of a generated white noise for 60 secondes.', 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'open_from_json', 'type': 'function', 'input_arguments': ['self', 'name', 'f', 'data'], 'summary': 'Open the data of a json file.', 'arguments': {0: {'name': 'name', 'type': 'str', 'description': ' name of the file (without the format)'}}, 'returns': {}, 'children': {}}
# {'name': 'plot_acquired_signal', 'type': 'function', 'input_arguments': ['self', 'fig', 'fig_bool'], 'summary': 'Plots the acquired signals with respect to time.', 'arguments': {0: {'name': 'fig', 'type': 'go.Figure, optional', 'description': ' figure where the lines should be traced. If there is no figure, one will be created. Defaults to None.'}}, 'returns': {}, 'children': {}}
# {'name': 'plot_av_fft', 'type': 'function', 'input_arguments': ['self', 'dB', 'fig', 'fig_bool', 'i', 'amplitudes', 'frequencies', 'frequencies_bool'], 'summary': 'Plots the smoothed averaged spectrum of the acquired signals.In order for this function to properly worked, the spectrum of the acquired signals should be computed first by running spectro_average.', 'arguments': {0: {'name': 'dB', 'type': 'bool, optional', 'description': ' Display the magnitude in dB if True. Defaults to False.'}, 1: {'name': 'fig', 'type': 'go.Figure, optional', 'description': ' figure where the lines should be traced. If there is no figure, one will be created. Defaults to None.'}}, 'returns': {}, 'children': {}}
# {'name': 'plot_fft_generated_signal', 'type': 'function', 'input_arguments': ['self', 'dB', 'fig_fft', 'amplitudes', 'frequencies', 'frequencies_bool'], 'summary': 'Plots the fft of the generated signal.In order for this function to properly worked, the spectrum of the generated signal should be computed first by running spectro_average.', 'arguments': {0: {'name': 'dB', 'type': 'bool, optional', 'description': ' Display the magnitude in dB if True. Defaults to False.'}}, 'returns': {}, 'children': {}}
# {'name': 'plot_generated_signal', 'type': 'function', 'input_arguments': ['self', 'fig_gs', 'fig_bool'], 'summary': 'Plots the generated signal with respect to time.', 'arguments': {0: {'name': 'fig_gs', 'type': 'go.Figure, optional', 'description': ' figure where the lines should be traced. If there is no figure, one will be created. Defaults to None.'}}, 'returns': {}, 'children': {}}
# {'name': 'save_to_cjson', 'type': 'function', 'input_arguments': ['self', 'name', 'H_ratio_conv', 'parameter', 'data', 'f'], 'summary': 'Saves the data of the object to json file.', 'arguments': {0: {'name': 'name', 'type': 'str', 'description': ' name of the file (without the format)'}}, 'returns': {}, 'children': {}}
# {'name': 'simple_acquisition', 'type': 'function', 'input_arguments': ['self', 'duration'], 'summary': 'Create a task to do a simple acquisition for a given duration. The acquired signals are then demeaned and converted from Volts to Pascal.', 'arguments': {0: {'name': 'duration', 'type': 'int', 'description': ' duration of the recording (sec)'}}, 'returns': {0: {'type': 'acquired_samples(array)', 'description': 'attribut of the class, 2-line array of the acquired samples from microphone 1 and 2'}}, 'children': {}}
# {'name': 'start_acquisition', 'type': 'function', 'input_arguments': ['self'], 'summary': 'Start an acquisition without signal generation.', 'arguments': {}, 'returns': {}, 'children': {}}
# {'name': 'average_smoothing', 'type': 'function', 'input_arguments': ['amplitudes', 'N', 'new_sig', 'i', 'val'], 'summary': 'Smooth an array of value with a sliding averaging windows', 'arguments': {0: {'name': 'amplitudes', 'type': 'array', 'description': ' values of the signal'}, 1: {'name': 'N', 'type': 'int, optional', 'description': ' number of samples of the sliding window. Defaults to 10.'}}, 'returns': {0: {'type': 'new signal (array)', 'description': 'smoothed averaged signal'}}, 'children': {}}
# {'name': 'combine_metric', 'type': 'function', 'input_arguments': ['signal_combined', 'metric', 'signal_large', 'signal_small', 'frequencies', 'nb_point', 'ref', 'func', 'w', 'weigth', 'frequencies_large', 'frequencies_small', 'signal_merged', 'signal_large_metric', 'signal_small_metric', 'i', 'merge'], 'summary': 'Combine the metric of two signals to reach a frequency range from 50 to 6400 Hz. Half of a gaussian curve is used on both ends of the signals to smooth the transition.The signal are combine with the average of the modulus of the metric. The resulting metric is then assign to the right attribut of the combined signal.', 'arguments': {0: {'name': 'signal_combined', 'type': 'TaskAcquisitionGeneration', 'description': ' Signal resulting from the combination of 2 signals'}, 1: {'name': 'metric', 'type': 'str', 'description': ' name of the metric to combine'}}, 'returns': {0: {'type': 'signal_merged(array)', 'description': 'result of the combination of the metric values of 2 signals'}}, 'children': {}}
# {'name': 'computation_R_coefficient', 'type': 'function', 'input_arguments': ['sig', 'f', 'mic1', 'mic2', 'H_ratio', 'expiksn', 'expiksp', 'R0'], 'summary': 'Compute the reflexion coefficient, as the mean of the magnitude of the R coeff computed for each segment of the spectrogram.', 'arguments': {0: {'name': 'sig', 'type': 'TaskAcquisitionGeneration', 'description': ' Signal'}}, 'returns': {0: {'type': 'R(array)', 'description': 'attribut of the input Signal, average of the modulus of the coefficient (real number)'}, 1: {'type': 'R_complx(array)', 'description': 'attribut of the input Signal, complexe coefficients computed for each segments of the spectrum.'}}, 'children': {}}
# {'name': 'computation_Z_impedance', 'type': 'function', 'input_arguments': ['self'], 'summary': 'Computation of the impedance.', 'arguments': {0: {'name': 'self', 'type': 'TaskAcquisitionGeneration', 'description': ' Signal'}}, 'returns': {0: {'type': 'Z(array)', 'description': 'attribut of the input Signal, average of the modulus of the impedance (real number)'}, 1: {'type': 'Z_complex(array)', 'description': 'attribut of the input Signal, complexe impedance computed for each segments of the spectrum.'}}, 'children': {}}
# {'name': 'computation_a_coefficient', 'type': 'function', 'input_arguments': ['self'], 'summary': 'Computation of the absorption coefficient.', 'arguments': {0: {'name': 'self', 'type': 'TaskAcquisitionGeneration', 'description': ' Signal'}}, 'returns': {0: {'type': 'a(array)', 'description': 'attribut of the input Signal, average of the modulus of the coefficient (real number)'}, 1: {'type': 'a_complex(array)', 'description': 'attribut of the input Signal, complexe coefficients computed for each segments of the spectrum.'}}, 'children': {}}
# {'name': 'compute_H12', 'type': 'function', 'input_arguments': ['signal', 'fft_0', 'fft_1'], 'summary': 'Computes the corrected transfert function of the mircophone 2 and 1.', 'arguments': {0: {'name': 'signal', 'type': 'TaskAcquisitionGeneration', 'description': ' Signal'}}, 'returns': {0: {'type': 'H12(array)', 'description': 'attribut of Signal, averaged transfert function computed for each segmente of the spectrum.'}}, 'children': {}}
# {'name': 'compute_coherence', 'type': 'function', 'input_arguments': ['signal', 'S'], 'summary': 'Computation of the coherence.', 'arguments': {0: {'name': 'self', 'type': 'TaskAcquisitionGeneration', 'description': ' Signal'}}, 'returns': {0: {'type': 'coh(array)', 'description': 'attribut of Signal, average of the modulus of the coherence (real number)'}, 1: {'type': 'coh_complex(array)', 'description': 'attribut of Signal, coherence computed for each segments of the spectrum.'}}, 'children': {}}
# {'name': 'frequencies_limits', 'type': 'function', 'input_arguments': ['signal', 'av', 'frequencies', 'frequencies_bool'], 'summary': 'Returns an array of booleen that matches the frequencies that are adequat to the set up.', 'arguments': {0: {'name': 'signal', 'type': 'TaskAcquisitionGeneration', 'description': ' Signal'}, 1: {'name': 'av', 'type': 'bool, optional', 'description': ' if true, the frequencies used to return the boolens are the frequencies that were computed with the computation of the periodogram . Defaults to True.'}}, 'returns': {0: {'type': 'frequencies_bool(array)', 'description': "Array of boolens, True is the frequencies is in the right range given the setting of the Signal's acquisition."}}, 'children': {}}
# {'name': 'hampel_filter', 'type': 'function', 'input_arguments': ['sig', 'win', 'n_sigmas', 'show', 'n', 'sig_output', 'k', 'indices', 'S0_list', 'i', 'median_win', 'S0'], 'summary': 'Hampel filter is used to remove outlier as explained in the following link https://blogs.sas.com/content/iml/2021/06/01/hampel-filter-robust-outliers.html.Hampel fliter uses a slinding window and based its algorithm on the computation of the median value.', 'arguments': {0: {'name': 'sig', 'type': 'array', 'description': ' values of the signal to filter'}, 1: {'name': 'win', 'type': 'int, optional', 'description': ' number of samples of the sliding windows. Defaults to 50.'}, 2: {'name': 'n_sigmas', 'type': 'int, optional', 'description': ' threshold, higher values leads to less exclusions. Defaults to 10.'}, 3: {'name': 'show', 'type': 'bool, optional', 'description': ' if show is true, an array of the applied thresholds is also return. Defaults to False.'}}, 'returns': {0: {'type': 'sig_output (array)', 'description': 'filtered signal'}, 1: {'type': 'indices (array)', 'description': 'indices of the removed samples'}}, 'children': {}}
# {'name': 'plot_av_fft_m', 'type': 'function', 'input_arguments': ['list_signals', 'dB', 'fig', 'smooth', 'fig_bool', 'signal', 'i', 'frequencies', 'frequencies_bool'], 'summary': 'Plot the averaged smoothed fourier transform of the signal.', 'arguments': {0: {'name': 'list_signals', 'type': '_type_', 'description': ' liste of the signals'}, 1: {'name': 'dB', 'type': 'bool, optional', 'description': ' If True, display the magnitude of the FFT in dB. Defaults to False.'}, 2: {'name': 'fig', 'type': 'go.Figure, optional', 'description': ' The graph will be displayed on the figure if provided. Defaults to None.'}, 3: {'name': 'smooth', 'type': 'bool, optional', 'description': ' if True, the values will be smoothed. Defaults to None.'}}, 'returns': {}, 'children': {}}
# {'name': 'plot_computation_metric_m', 'type': 'function', 'input_arguments': ['list_signals', 'metric', 'fig', 'fig_bool', 'ref', 'func', 'sig', 'frequencies_bool', 'y'], 'summary': 'Plot the values of the R coefficient/ a coefficient / Z impedannce', 'arguments': {0: {'name': 'list_signals', 'type': '_type_', 'description': ' _description_'}, 1: {'name': 'metric', 'type': '_type_', 'description': ' _description_'}, 2: {'name': 'fig', 'type': '_type_, optional', 'description': ' _description_. Defaults to None.'}, 3: {'name': 'H_', 'type': 'bool, optional', 'description': ' _description_. Defaults to False.'}}, 'returns': {}, 'children': {}}
# {'name': 'rms', 'type': 'function', 'input_arguments': ['x'], 'summary': 'Computes the RMS value of the signal', 'arguments': {0: {'name': 'x', 'type': 'array', 'description': ' liste of values'}}, 'returns': {0: {'type': 'rms (float)', 'description': 'rms'}}, 'children': {}}
# {'name': 'spectro_average', 'type': 'function', 'input_arguments': ['signal', 'df', 'fe', 'N', 'overlap', 'i', 'f_ov', 't_ov', 'Sxx_ov', 'Sxx_ov_av'], 'summary': "Compute the averaged smooth Fourier Transform for the both microphones of the input signal.Code:The function uses the function spectrogram of the scipy module to segment the signal so that the frequency resolution is 2 Hz and the windows overlap is 50%.The 'returned' variables represent the signal attributes that are modified by the function.The number of segment can be computed as follows: len(signal)-overlap)/(N-overlap) with N = int(fe/df)", 'arguments': {0: {'name': 'signal', 'type': 'TaskAcquisitionGeneration', 'description': ' Signal'}, 1: {'name': 'df', 'type': 'float', 'description': ' frequency precision'}}, 'returns': {0: {'type': 'av_fft(array)', 'description': 'attribut of the signal, 2-line array that stores smoothed averaged magnitude of the spectrum of the acquired samples of signal.'}, 1: {'type': 'av_f(array)', 'description': 'attribut of the signal, frequencies of the spectrum'}, 2: {'type': 'seg(array)', 'description': 'attribut of the signal, segments of the spectrogramm, each row stores the spectrum of a segment.'}}, 'children': {}}
